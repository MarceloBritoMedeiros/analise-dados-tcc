# %%
import livepopulartimes
import requests

# %%
livepopulartimes.get_populartimes_by_address("Ponto de Ônibus Estr. do Campo Limpo, 5930, São Paulo, Brazil")
# Out:
# {'rating': 5,
#  'rating_n': 1,
#  'populartimes': [{'name': 'Monday',
#    'data': [21,
#     12,
#     6,
#     5,
#     28,
#     54,
#     75,
#     85,
#     69,
#     60,
#     49,
#     44,
#     41,
#     35,
#     30,
#     28,
#     32,
#     46,
#     54,
#     53,
#     43,
#     37,
#     34,
#     27]},
#   {'name': 'Tuesday',
#    'data': [15,
#     7,
#     8,
#     14,
#     34,
#     61,
#     87,
#     100,
#     83,
#     69,
#     58,
#     49,
#     42,
#     35,
#     29,
#     32,
#     32,
#     40,
#     44,
#     50,
#     47,
#     43,
#     42,
#     36]},
#   {'name': 'Wednesday',
#    'data': [25,
#     18,
#     14,
#     18,
#     29,
#     55,
#     80,
#     95,
#     83,
#     71,
#     58,
#     49,
#     42,
#     40,
#     38,
#     35,
#     36,
#     42,
#     48,
#     50,
#     47,
#     42,
#     37,
#     31]},
#   {'name': 'Thursday',
#    'data': [17,
#     9,
#     7,
#     14,
#     26,
#     50,
#     77,
#     95,
#     84,
# ...

# %%
livepopulartimes.get_populartimes_by_address("Estação Jabaquara, São Paulo, Brazil")
# Out:
# {'rating': 4.3,
#  'rating_n': 1687,
#  'current_popularity': 21,
#  'populartimes': [{'name': 'Monday',
#    'data': [11,
#     5,
#     2,
#     3,
#     17,
#     39,
#     64,
#     80,
#     76,
#     64,
#     55,
#     52,
#     51,
#     50,
#     50,
#     55,
#     67,
#     79,
#     83,
#     71,
#     52,
#     36,
#     26,
#     17]},
#   {'name': 'Tuesday',
#    'data': [8,
#     3,
#     2,
#     5,
#     15,
#     36,
#     60,
#     76,
#     74,
#     62,
#     52,
#     48,
#     48,
#     48,
#     48,
#     54,
#     66,
#     81,
#     85,
#     74,
#     54,
#     38,
#     27,
#     18]},
#   {'name': 'Wednesday',
#    'data': [9,
#     4,
#     2,
#     5,
#     16,
#     37,
#     62,
#     78,
#     75,
#     63,
#     53,
#     50,
#     50,
#     49,
#     50,
#     56,
#     70,
#     85,
#     91,
#     78,
#     57,
#     38,
#     26,
#     18]},
#   {'name': 'Thursday',
#    'data': [9,
#     4,
#     2,
#     5,
#     15,
#     37,
#     61,
# ...

# %%
import json

# Abrindo o arquivo JSON e carregando para um dicionário
with open('stations.json', encoding='utf-8') as f:
    data = json.load(f)

# %%
estacoes = []

# %%
for i in data.keys():
    estacoes.append(data[i]["title"])

# %%
estacoes
# Out:
# ['Jabaquara',
#  'Conceição',
#  'São Judas',
#  'Saúde',
#  'Praça Da árvore',
#  'Santa Cruz',
#  'Vila Mariana',
#  'Ana Rosa',
#  'Paraíso',
#  'Vergueiro',
#  'São Joaquim',
#  'Liberdade',
#  'Sé',
#  'São Bento',
#  'Luz',
#  'Tiradentes',
#  'Armênia',
#  'Portuguesa - Tietê',
#  'Carandiru',
#  'Santana',
#  'Jardim São Paulo - Ayrton Senna',
#  'Parada Inglesa',
#  'Tucuruvi',
#  'Vila Prudente',
#  'Tamanduateí',
#  'Sacomã',
#  'Alto Do Ipiranga',
#  'Santos - Imigrantes',
#  'Chácara Klabin',
#  'Brigadeiro',
#  'Trianon - Masp',
#  'Consolação',
#  'Clínicas',
#  'S. N. Sra. De Fátima - Sumaré',
#  'Vila Madalena',
#  'Corinthians - Itaquera',
#  'Artur Alvim',
#  'Patriarca',
#  'Guilhermina - Esperança',
#  'Vila Matilde',
#  'Penha',
#  'Carrão',
#  'Tatuapé',
#  'Belém',
#  'Bresser - Mooca',
#  'Brás',
#  'Pedro Ii',
#  'Anhangabaú',
#  'República',
#  'Santa Cecília',
#  'Marechal Deodoro',
#  'Palmeiras - Barra Funda',
#  'Paulista',
#  'Faria Lima',
# ...

# %%
len(estacoes)
# Out:
# 62

# %%
lotacoes = []
for i in estacoes:
    lotacoes.append((i, livepopulartimes.get_populartimes_by_address(f"Estação {i}, São Paulo, Brazil")))

# %%
len(lotacoes)
# Out:
# 62

# %%
lotacoes[0][0]
# Out:
# 'Jabaquara'

# %%
lotacoes_popular_times = []
n = []
c1 = 0
c2 = 0

for i in lotacoes:
    try:
        i[1]['populartimes']
        lotacoes_popular_times.append(i)
        c1+=1
    except:
        n.append(i[0])
        print(i[0])
        c2+=1
# Out:
# Saúde
# São Joaquim
# Sé
# São Bento
# Armênia
# Tamanduateí
# Sacomã
# Trianon - Masp
# Artur Alvim
# Guilhermina - Esperança
# Vila Matilde
# Carrão
# Tatuapé
# Brás
# Butantã
# Santo Amaro
# Largo Treze

# %%
livepopulartimes.get_populartimes_by_address(f"Estação Brás de Metrô, São Paulo, Brazil")
# Out:
# {'name': None,
#  'place_id': None,
#  'address': None,
#  'coordinates': {'lat': None, 'lng': None},
#  'categories': None,
#  'place_types': None,
#  'current_popularity': None,
#  'popular_times': None}

# %%
place_ids = []
for i in estacoes:
    place_ids.append(requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?address=Estação {i}&key=AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM").json())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 3
#       1 place_ids = []
#       2 for i in estacoes:
# ----> 3     place_ids.append(requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?address=Estação {i}&key=AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM").json())
#
# File c:\Development\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Development\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
# ...

# %%
def retorna_lotacoes(lista):
    place_ids = []
    for i in lista:
        place_ids.append(requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?address=Estação {i}&key=AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM").json())
        
    place_ids2 = []
    for i in place_ids:
        place_ids2.append(i["results"][0]["place_id"])

    lotacoes2 = []
    for i in place_ids2:
        lotacoes2.append(populartimes.get_id("AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM", i))
    return lotacoes2

# %%
m = retorna_lotacoes(n)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 m = retorna_lotacoes(n)
#
# Cell In[98], line 8, in retorna_lotacoes(lista)
#       6 place_ids2 = []
#       7 for i in place_ids:
# ----> 8     place_ids2.append(i["results"][0]["place_id"])
#      10 lotacoes2 = []
#      11 for i in place_ids2:
#
# IndexError: list index out of range

# %%
import populartimes

# %%
n
# Out:
# ['Saúde',
#  'São Joaquim',
#  'Sé',
#  'São Bento',
#  'Armênia',
#  'Tamanduateí',
#  'Sacomã',
#  'Trianon - Masp',
#  'Artur Alvim',
#  'Guilhermina - Esperança',
#  'Vila Matilde',
#  'Carrão',
#  'Tatuapé',
#  'Brás',
#  'Butantã',
#  'Santo Amaro',
#  'Largo Treze']

# %%
for i in m:
    try:
        i['populartimes']
        c1+=1
    except:
        print(i['name'])
        c2+=1
# Out:
# São Joaquim
# Sé
# São Bento
# Armênia
# Estação Trianon Masp
# Artur Alvim
# Vila Matilde
# Butantã
# Santo Amaro
# Largo Treze

# %%
retorna_lotacoes([" de Metrô Santo Amaro"])
# Out:
# [{'id': 'ChIJyX2zR_lQzpQRN8gDn5OnEk4',
#   'name': 'Santo Amaro',
#   'address': 'Santo Amaro, São Paulo - State of São Paulo, Brazil',
#   'types': ['sublocality_level_1', 'sublocality', 'political'],
#   'coordinates': {'lat': -23.6536633, 'lng': -46.7066927}}]

# %%
n
# Out:
# ['Saúde',
#  'São Joaquim',
#  'Sé',
#  'São Bento',
#  'Armênia',
#  'Tamanduateí',
#  'Sacomã',
#  'Trianon - Masp',
#  'Artur Alvim',
#  'Guilhermina - Esperança',
#  'Vila Matilde',
#  'Carrão',
#  'Tatuapé',
#  'Brás',
#  'Butantã',
#  'Santo Amaro',
#  'Largo Treze']

# %%
m = []
for i in n:
    m.append((i, livepopulartimes.get_populartimes_by_address(f"Estação {i} do Metrô, São Paulo, Brazil")))

# %%
m
# Out:
# [{'rating': 4.3,
#   'rating_n': 325,
#   'current_popularity': 1,
#   'populartimes': [{'name': 'Monday',
#     'data': [8,
#      3,
#      1,
#      2,
#      13,
#      31,
#      52,
#      68,
#      68,
#      61,
#      56,
#      58,
#      61,
#      62,
#      62,
#      66,
#      79,
#      92,
#      95,
#      80,
#      59,
#      42,
#      31,
#      20]},
#    {'name': 'Tuesday',
#     'data': [10,
#      4,
#      2,
#      4,
#      13,
#      32,
#      56,
#      73,
#      75,
#      65,
#      58,
#      58,
#      60,
#      61,
#      62,
#      68,
#      80,
#      93,
#      97,
#      84,
#      63,
#      45,
#      33,
#      22]},
#    {'name': 'Wednesday',
#     'data': [11,
#      4,
#      2,
#      4,
#      14,
#      33,
#      57,
#      74,
#      74,
#      65,
#      59,
#      59,
#      61,
#      62,
#      62,
#      68,
#      81,
#      95,
#      100,
#      85,
#      63,
#      44,
#      33,
#      22]},
#    {'name': 'Thursday',
# ...

# %%
lotacoes_popular_times2 = []
nn = []
c1 = 0
c2 = 0

for i in m:
    try:
        i[1]['populartimes']
        lotacoes_popular_times2.append(i)
        c1+=1
    except:
        nn.append(i[0])
        print(i[0])
        c2+=1
# Out:
# São Joaquim
# Armênia
# Tamanduateí
# Sacomã
# Brás
# Santo Amaro

# %%
v = livepopulartimes.get_populartimes_by_address(f"Estação Vila Sônia - Prof. Elizabeth Tenreiro (Linha 4-Amarela do Metrô), São Paulo - SP")

# %%
p = livepopulartimes.get_populartimes_by_address(f"Estação Sacomã Praça Altemar Dutra, São Paulo - SP")

# %%
s = livepopulartimes.get_populartimes_by_address(f"Estação Santo Amaro Avenida Guido Caloi, São Paulo - SP")

# %%
lotacoes_full = lotacoes_popular_times + lotacoes_popular_times2

# %%
len(lotacoes_popular_times)
# Out:
# 45

# %%
len(lotacoes_full)
# Out:
# 56

# %%
len(estacoes)
# Out:
# 62

# %%
lotacoes_full
# Out:
# [('Jabaquara',
#   {'rating': 4.3,
#    'rating_n': 1687,
#    'current_popularity': 21,
#    'populartimes': [{'name': 'Monday',
#      'data': [11,
#       5,
#       2,
#       3,
#       17,
#       39,
#       64,
#       80,
#       76,
#       64,
#       55,
#       52,
#       51,
#       50,
#       50,
#       55,
#       67,
#       79,
#       83,
#       71,
#       52,
#       36,
#       26,
#       17]},
#     {'name': 'Tuesday',
#      'data': [8,
#       3,
#       2,
#       5,
#       15,
#       36,
#       60,
#       76,
#       74,
#       62,
#       52,
#       48,
#       48,
#       48,
#       48,
#       54,
#       66,
#       81,
#       85,
#       74,
#       54,
#       38,
#       27,
#       18]},
#     {'name': 'Wednesday',
#      'data': [9,
#       4,
#       2,
#       5,
#       16,
#       37,
#       62,
#       78,
#       75,
#       63,
#       53,
#       50,
#       50,
#       49,
#       50,
#       56,
#       70,
#       85,
# ...

# %%
lotacoes_full2 = []
for i in lotacoes_full:
    lotacoes_full2.append(i[1])

# %%
type(lotacoes_full2)
# Out:
# list

# %%
lotacoes_full2.append(v)
lotacoes_full2.append(p)
lotacoes_full2.append(s)

# %%
lotacoes_full2_pd = pd.DataFrame(lotacoes_full2)

# %%
import pandas as pd

# %%
lotacoes_full2_pd[lotacoes_full2_pd["name"].str.contains("Vila")].head(20)
# Out:
#     rating  rating_n  current_popularity  \
# 5      4.3       504                  20
# 18     4.3      4073                  13
# 26     4.5       411                  23
# 43     4.3       272                  33
# 51     4.3       478                  34
# 56     4.6      2679                  21
#
#                                          populartimes  \
# 5   [{'name': 'Monday', 'data': [8, 4, 2, 3, 13, 3...
# 18  [{'name': 'Monday', 'data': [5, 2, 1, 2, 14, 3...
# 26  [{'name': 'Monday', 'data': [8, 4, 2, 3, 10, 2...
# 43  [{'name': 'Monday', 'data': [11, 6, 4, 5, 17, ...
# 51  [{'name': 'Monday', 'data': [15, 8, 4, 4, 17, ...
# 56  [{'name': 'Monday', 'data': [0, 0, 0, 0, 20, 4...
#
#                                                  name  \
# 5                                        Vila Mariana
# 18                                      Vila Prudente
# 26                                      Vila Madalena
# 43                                   Vila das Belezas
# ...

# %%
lotacoes_full2_pd.to_json("lotacoes_metro.json")

# %%
with open("lotacoes_metro.json", "w") as json_file:
    # Convert dictionary to JSON and write to file
    json.dump(lotacoes_full2, json_file)

# %%
import populartimes
import requests

# %%
info = "Term. Jabaquara, São Paulo, Brazil"

# %%
place_ids = []

# %%
len(place_ids)
# Out:
# 92

# %%
for i in estacoes:
    place_ids.append(requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?address=Estação {i}&key=AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM").json())

# %%
lotacoes = []

# %%
for i in place_ids:
    lotacoes.append(i["results"][0]["place_id"])

# %%
lotacoes
# Out:
# ['ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'ChIJV8LdrPpazpQRpB9Sj_uJ1Ww',
#  'ChIJQRIx7VdazpQRgL9W35lxi-M',
#  'ChIJfYbHU1BazpQRHyKqfBrRyfE',
#  'ChIJw8hM5rRbzpQRQdtJ2ivTZ3U',
# ...

# %%
place_ids
# Out:
# [{'results': [{'address_components': [{'long_name': 'Jabaquara',
#       'short_name': 'Jabaquara',
#       'types': ['establishment',
#        'point_of_interest',
#        'subway_station',
#        'transit_station']},
#      {'long_name': 'Rua dos Jequitibás',
#       'short_name': 'R. dos Jequitibás',
#       'types': ['route']},
#      {'long_name': 'Jardim Oriental',
#       'short_name': 'Jardim Oriental',
#       'types': ['political', 'sublocality', 'sublocality_level_1']},
#      {'long_name': 'São Paulo',
#       'short_name': 'São Paulo',
#       'types': ['administrative_area_level_2', 'political']},
#      {'long_name': 'São Paulo',
#       'short_name': 'SP',
#       'types': ['administrative_area_level_1', 'political']},
#      {'long_name': 'Brazil',
#       'short_name': 'BR',
#       'types': ['country', 'political']},
#      {'long_name': '04309-011',
#       'short_name': '04309-011',
#       'types': ['postal_code']}],
# ...

# %%
with open("place_ids.json", "w") as json_file:
    json.dump(place_ids, json_file)

# %%
import json

# Abrindo o arquivo JSON e carregando para um dicionário
with open('stations.json', encoding='utf-8') as f:
    data = json.load(f)

# %%
estacoes = []

# %%
for i in data.keys():
    estacoes.append(data[i]["location"]["address"])

# %%
estacoes
# Out:
# ['Term. Jabaquara, São Paulo, Brazil',
#  'Conceição, Vila Guarani, Sao Paulo - São Paulo, Brazil',
#  'São Judas, São Paulo, Brazil',
#  'Saúde, Sao Paulo - São Paulo, Brazil',
#  'Praça Da Árvore, São Paulo, Brazil',
#  'Santa Cruz, São Paulo, Brazil',
#  'Vila Mariana, São Paulo, Brazil',
#  'Ana Rosa, São Paulo, Brazil',
#  'Estação Paraíso, São Paulo, Brazil',
#  'Vergueiro, São Paulo, Brazil',
#  'São Joaquim, São Paulo, Brazil',
#  'Estação Liberdade do Metro, São Paulo, Brazil',
#  'Praça da Sé, Centro, Sao Paulo - São Paulo, Brazil',
#  'São Bento, São Paulo, Brazil',
#  'Estação Luz do Metrô - Avenida Cásper Líbero, Luz, Sao Paulo - São Paulo, Brazil',
#  'Tiradentes, Luz, Sao Paulo - São Paulo, Brazil',
#  'Armênia, Luz, Sao Paulo - São Paulo, Brazil',
#  'Portuguesa-tietê, Santana, Sao Paulo - São Paulo, Brazil',
#  'Carandiru, Santana, Sao Paulo - São Paulo, Brazil',
#  'Estação Santana - Rua Doutor César, Santana, Sao Paulo - São Paulo, Brazil',
# ...

# %%
lotacoes2 = []

# %%
for i in lotacoes:
    lotacoes2.append(populartimes.get_id("AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM", i))

# %%
c1 = 0
c2 = 0

# %%
for i in lotacoes2:
    try:
        i['populartimes']
        c1+=1
    except:
        print(i['name'])
        c2+=1
# Out:
# São Judas
# São Judas
# Praça da Árvore
# Santa Cruz
# São Judas
# Praça da Árvore
# Santa Cruz
# Vila Mariana
# Paraíso
# São Joaquim
# São Paulo
# Sé
# São Bento
# Luz
# Armênia
# Carandiru
# Santana
# Parada Inglesa
# Tamanduateí
# Brigadeiro
# Clínicas
# Estação Artur Alvim
# Patriarca
# Estação Guilhermina Esperança
# Estação Vila Matilde
# Estação Anhangabaú
# República
# Paulista
# Faria Lima
# Rua Gilberto Sabino
# Estacao
# Campo Limpo
# Vila das Belezas
# West Zone of São Paulo
# Largo Treze

# %%
len(lotacoes2)
# Out:
# 119

# %%
c1
# Out:
# 84

# %%
c2
# Out:
# 35

# %%
lotacoes2[0]
# Out:
# {'id': 'ChIJGeqxXN1azpQReOktTOQJGK8',
#  'name': 'Jabaquara',
#  'address': 'Av. dos Jequitibás - Jabaquara, São Paulo - SP, 04309-011, Brazil',
#  'types': ['subway_station',
#   'transit_station',
#   'point_of_interest',
#   'establishment'],
#  'coordinates': {'lat': -23.6461957, 'lng': -46.6407825},
#  'rating': 4.3,
#  'rating_n': 1687,
#  'current_popularity': 77,
#  'populartimes': [{'name': 'Monday',
#    'data': [10,
#     5,
#     2,
#     3,
#     14,
#     33,
#     54,
#     68,
#     65,
#     56,
#     49,
#     47,
#     47,
#     47,
#     47,
#     52,
#     63,
#     73,
#     77,
#     67,
#     52,
#     38,
#     28,
#     20]},
#   {'name': 'Tuesday',
#    'data': [11,
#     5,
#     2,
#     5,
#     14,
#     34,
#     56,
#     71,
#     70,
#     60,
#     51,
#     48,
#     48,
#     48,
#     48,
#     54,
#     64,
#     77,
#     81,
#     70,
#     52,
#     37,
#     27,
#     18]},
#   {'name': 'Wednesday',
#    'data': [10,
#     4,
#     2,
# ...

# %%
i="de Metrô Paulista"
u = requests.get(f"https://maps.googleapis.com/maps/api/geocode/json?address=Estação {i}&key=AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM").json()

# %%
place = u["results"][0]["place_id"]
print(place)
# Out:
# ChIJseZhoi1YzpQRO0jBy2su61w

# %%
populartimes.get_id("AIzaSyALXezoywqm1Vfc4KCU5YEnCQOSGSvSPPM", "ChIJGzTMYr9ZzpQRr9Oiuob1sKQ")
# Out:
# {'id': 'ChIJGzTMYr9ZzpQRr9Oiuob1sKQ',
#  'name': 'Estação Paulista',
#  'address': 'R. Bela Cintra, 1032 - Consolação, São Paulo - SP, 01415-002, Brazil',
#  'types': ['point_of_interest', 'establishment'],
#  'coordinates': {'lat': -23.5557881, 'lng': -46.66165170000001},
#  'rating': 4.6,
#  'rating_n': 75,
#  'populartimes': [{'name': 'Monday',
#    'data': [0,
#     0,
#     0,
#     0,
#     4,
#     2,
#     10,
#     23,
#     50,
#     51,
#     61,
#     67,
#     82,
#     79,
#     69,
#     61,
#     55,
#     46,
#     29,
#     27,
#     43,
#     55,
#     56,
#     39]},
#   {'name': 'Tuesday',
#    'data': [0,
#     0,
#     0,
#     0,
#     6,
#     6,
#     15,
#     12,
#     24,
#     36,
#     65,
#     78,
#     98,
#     89,
#     95,
#     91,
#     99,
#     84,
#     69,
#     45,
#     39,
#     41,
#     50,
#     59]},
#   {'name': 'Wednesday',
#    'data': [0,
#     0,
#     0,
#     0,
#     4,
#     6,
#     9,
#     21,
#     28,
#     40,
# ...

# %%
"latitude": -23.6244547,
"longitude": -46.6379525
